# %%
# !pip install datasets transformers noisereduce librosa evaluate
# !pip install jiwer
# !pip install transformers[torch]
# !pip install accelerate -U
# Out:
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Collecting noisereduce
#   Downloading noisereduce-3.0.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.2.post1)
# Collecting evaluate
#   Downloading evaluate-0.4.2-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.5.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from noisereduce) (1.11.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from noisereduce) (3.7.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.0.8)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (4.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.16.0)
# Installing collected packages: xxhash, requests, pyarrow, dill, multiprocess, noisereduce, datasets, evaluate
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 16.1.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 16.1.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 evaluate-0.4.2 multiprocess-0.70.16 noisereduce-3.0.2 pyarrow-16.1.0 requests-2.32.3 xxhash-3.4.1
# Collecting jiwer
#   Downloading jiwer-3.0.4-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from jiwer) (8.1.7)
# Collecting rapidfuzz<4,>=3 (from jiwer)
#   Downloading rapidfuzz-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 12.1 MB/s eta 0:00:00
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.4 rapidfuzz-3.9.3
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (4.66.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from transformers[torch]) (2.3.0+cu121)
# Collecting accelerate>=0.21.0 (from transformers[torch])
#   Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.21.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers[torch]) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->transformers[torch])
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->transformers[torch])
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->transformers[torch])
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->transformers[torch])
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->transformers[torch])
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->transformers[torch])
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->transformers[torch])
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->transformers[torch])
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->transformers[torch]) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->transformers[torch])
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 58.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers[torch]) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->transformers[torch]) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->transformers[torch]) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.31.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.31.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.5.40)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch h5py transformers
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.5.40)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.25.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import h5py
import torch
from transformers import WhisperForConditionalGeneration, WhisperProcessor

def load_model_from_h5(model, h5_path):
    with h5py.File(h5_path, 'r') as h5file:
        for name, param in model.named_parameters():
            param_data = torch.tensor(h5file[name][...])
            param.data.copy_(param_data)

# Example usage
model_name = "openai/whisper-small"  # Use the appropriate model name
h5_file_path = "/content/drive/MyDrive/whisper_model_weights_judy.h5"

# Load the model and processor
processor = WhisperProcessor.from_pretrained(model_name)
model = WhisperForConditionalGeneration.from_pretrained(model_name)

# Load the weights from the H5 file
load_model_from_h5(model, h5_file_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/1.97k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/967M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.87k [00:00<?, ?B/s]

# %%
# Extract the dataset
# !tar -zxvf /content/drive/MyDrive/cv-corpus-12.0-delta-2022-12-07-en.tar.gz -C /content/
# Out:
# Streaming output truncated to the last 5000 lines.
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36452452.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453434.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453435.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453436.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453437.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453438.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453449.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453450.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453451.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453452.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453453.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453454.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453455.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453456.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453457.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453458.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453459.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453460.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453461.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453462.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453463.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453464.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453465.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453466.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453467.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453468.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453469.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453470.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453471.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453472.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453473.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453474.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453475.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453476.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453477.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453478.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453568.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453569.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453570.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453571.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453572.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453603.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453604.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453605.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453606.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453607.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453621.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453623.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453625.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453626.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453627.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453633.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453634.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453635.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453636.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453637.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453707.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453708.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453709.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453715.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453716.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453717.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453718.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453719.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453720.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453721.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453722.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453723.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453729.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453730.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453736.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453737.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453741.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453744.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453745.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453746.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453757.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453758.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453759.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453760.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453761.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453762.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453763.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453764.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453765.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453766.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453771.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453773.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453774.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453775.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453780.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453782.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453783.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453784.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453785.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453786.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453794.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453795.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453796.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453797.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453798.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453804.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453805.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453806.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453807.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453808.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453809.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453810.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453811.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453812.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453813.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453814.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453815.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453816.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453817.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453818.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453819.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453820.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453821.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453822.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453823.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453824.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453825.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453826.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453827.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453828.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453829.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453830.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453831.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453832.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453833.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453834.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453835.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453836.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453837.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453838.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453839.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453840.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453841.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453842.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453843.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453844.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453845.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453846.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453847.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453848.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453849.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453850.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453851.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453857.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453858.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453864.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453865.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453866.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453867.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453868.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453869.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453870.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453871.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453872.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453873.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453874.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453875.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453876.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453877.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453878.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453894.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453895.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453896.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453897.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453898.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453899.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453900.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453901.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453902.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453903.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453904.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453905.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453906.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453907.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453908.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453909.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453910.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453916.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453917.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453918.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453919.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453920.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453921.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453922.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453923.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453924.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453925.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453926.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453927.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453928.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453929.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453930.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453931.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453932.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453933.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453934.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453935.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453936.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453937.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453938.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453944.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453945.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453946.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453947.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453948.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453959.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453960.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453961.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453962.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453963.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453964.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453965.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453966.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453967.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453968.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453969.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453970.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453971.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453972.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453973.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453979.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453980.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453981.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453982.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453983.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453984.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453985.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453986.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453987.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453988.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453989.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453990.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453991.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453992.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453993.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453994.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453995.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453996.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453997.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453998.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36453999.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454000.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454004.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454007.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454008.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454009.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454010.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454016.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454017.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454018.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454030.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454040.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454041.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454042.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454043.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454044.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454045.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454046.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454047.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454048.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454049.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454055.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454056.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454057.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454058.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454247.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454248.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454249.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454251.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454257.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454258.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454260.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454263.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454264.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454265.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454271.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454272.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454273.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454274.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454280.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454281.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454282.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454283.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454284.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454285.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454286.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454287.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454288.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454291.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454295.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454299.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454307.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454308.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454309.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454310.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454338.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454341.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454342.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454343.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454344.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454355.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454356.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454357.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454358.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454359.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454375.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454376.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454377.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454378.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454386.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454390.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454391.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454392.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454393.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454394.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454415.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454416.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454417.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454418.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454419.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454430.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454431.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454432.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454433.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454444.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454445.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454446.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454452.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454453.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454454.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454465.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454471.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454472.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454478.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454484.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454485.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454486.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454492.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454493.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454494.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454495.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454496.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454497.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454498.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454499.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454510.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454511.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454517.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454518.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454524.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454533.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454536.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454542.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454543.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454544.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454550.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454551.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454557.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454558.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454559.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454575.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454576.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454577.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454578.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454579.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454989.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454990.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454991.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454992.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36454993.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455009.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455010.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455011.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455012.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455013.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455014.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455015.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455016.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455017.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455018.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455139.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455140.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455141.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455142.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455143.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455144.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455145.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455146.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455147.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455148.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455149.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455150.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455151.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455152.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455153.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455154.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455155.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455156.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455157.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455158.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455159.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455160.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455161.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455162.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455163.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455169.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455170.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455171.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455172.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455173.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455179.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455180.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455181.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455182.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455183.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455189.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455190.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455191.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455192.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455193.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455194.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455195.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455196.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455197.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455198.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455199.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455200.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455201.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455202.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455203.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455204.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455205.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455206.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455207.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455208.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455209.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455210.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455211.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455212.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455213.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455214.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455215.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455216.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455217.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455218.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455219.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455220.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455221.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455222.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455223.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455224.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455225.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455226.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455227.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455228.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455229.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455230.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455231.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455232.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455233.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455234.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455235.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455236.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455237.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455238.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455239.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455240.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455241.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455242.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455248.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455249.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455250.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455251.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455252.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455253.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455254.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455255.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455256.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455257.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455258.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455259.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455260.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455261.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455262.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455268.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455269.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455270.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455271.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455272.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455283.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455284.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455285.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455286.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455287.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455293.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455294.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455295.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455296.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455297.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455304.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455305.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455306.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455307.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455309.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455325.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455326.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455327.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455328.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455329.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455346.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455347.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455348.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455349.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455350.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455351.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455352.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455353.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455354.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455355.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455356.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455357.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455358.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455359.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455360.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455478.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455479.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455480.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455481.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455482.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455483.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455484.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455485.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455486.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455487.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455493.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455494.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455495.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455496.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455497.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455498.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455499.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455500.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455501.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455502.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455690.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455691.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455692.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455693.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455694.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455922.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455923.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455924.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455925.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455926.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455927.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455928.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455929.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455930.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455931.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455937.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455938.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455939.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455940.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455941.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455947.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455948.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455949.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455950.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455951.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455957.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455958.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455959.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455960.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455961.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455967.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455968.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455969.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455970.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36455971.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456012.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456013.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456014.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456015.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456016.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456017.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456018.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456019.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456020.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456021.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456022.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456023.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456024.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456025.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456026.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456027.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456028.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456029.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456030.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456031.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456032.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456033.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456034.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456035.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456036.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456037.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456038.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456039.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456040.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456041.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456042.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456043.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456044.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456045.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456046.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456047.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456048.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456049.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456050.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456051.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456052.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456053.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456054.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456055.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456056.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456057.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456058.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456059.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456060.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456061.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456072.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456073.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456074.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456075.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456076.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456077.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456078.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456079.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456080.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456081.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456082.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456083.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456084.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456085.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456086.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456087.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456088.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456089.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456090.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456091.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456092.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456093.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456094.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456095.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456096.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456097.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456098.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456099.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456100.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456101.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456233.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456234.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456235.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456236.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36456237.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457078.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457084.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457085.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457086.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457087.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457093.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457094.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457095.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457096.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457097.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457116.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457127.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457136.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36457137.mp3
# ...
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523817.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523818.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523819.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523820.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523821.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523822.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523823.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523824.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523825.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523826.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523827.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523828.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523829.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523830.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523831.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523832.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523833.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523834.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523835.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523836.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523837.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523892.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523893.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523894.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523895.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523896.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523897.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523898.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523899.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523900.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523901.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523902.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523903.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523904.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523905.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523906.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523907.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523908.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523909.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523910.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523927.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523928.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523929.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523930.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523931.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523932.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523933.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523934.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523935.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523937.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523938.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523939.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523940.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523941.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523942.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523943.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523944.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523945.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523952.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523953.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523962.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523963.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523964.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523965.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523966.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523977.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523978.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523979.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523980.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523981.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523982.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523983.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523984.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523985.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36523986.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524004.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524005.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524006.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524007.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524008.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524009.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524010.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524011.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524012.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524013.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524014.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524025.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524026.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524027.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524028.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524029.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524045.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524046.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524047.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524048.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524049.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524210.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524211.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524212.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524213.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524214.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524238.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524239.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524240.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524242.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524243.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524271.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524273.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524274.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524275.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524277.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524281.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524282.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524283.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524284.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524285.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524312.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524313.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524318.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36524319.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525034.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525036.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525037.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525038.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525039.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525078.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525079.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525080.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525081.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525082.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525840.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525841.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525862.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525863.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525864.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525865.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36525866.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526477.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526478.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526479.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526480.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526481.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526527.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526528.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526529.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526530.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526531.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526623.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526624.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526625.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526626.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526627.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526633.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526634.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526635.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526636.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526637.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526638.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526639.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526640.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526641.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36526642.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527704.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527705.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527706.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527707.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527708.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527771.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527772.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527773.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527928.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527929.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527930.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527931.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527932.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527948.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527949.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527950.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527951.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527952.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527975.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527976.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527977.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527978.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36527979.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528104.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528105.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528106.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528107.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528108.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528129.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528130.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528131.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528132.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528133.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528486.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528487.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528488.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528489.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528490.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528556.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528557.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528559.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528560.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528561.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528855.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528856.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528857.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528858.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528860.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528905.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528906.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528907.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528908.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36528909.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36529415.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36529416.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36529417.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36529418.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36529419.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36529769.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36529770.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36529771.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36529772.mp3
# cv-corpus-12.0-delta-2022-12-07/en/clips/common_voice_en_36529773.mp3
# cv-corpus-12.0-delta-2022-12-07/en/invalidated.tsv
# cv-corpus-12.0-delta-2022-12-07/en/other.tsv
# cv-corpus-12.0-delta-2022-12-07/en/reported.tsv
# cv-corpus-12.0-delta-2022-12-07/en/validated.tsv

# %%
# Log in to Hugging Face
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Import necessary libraries
import pandas as pd
import os
from datasets import Dataset, DatasetDict, Audio, load_metric
from transformers import WhisperProcessor
import noisereduce as nr

import librosa
import torch
from dataclasses import dataclass
from typing import Any, Dict, List, Union
from transformers import WhisperForConditionalGeneration, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers.models.whisper.english_normalizer import BasicTextNormalizer
import evaluate
from functools import partial

# %%
from datasets import Dataset, DatasetDict, Audio
import pandas as pd
import os
import librosa

# Define paths
metadata_path = '/content/cv-corpus-12.0-delta-2022-12-07/en/validated.tsv'
clips_path = '/content/cv-corpus-12.0-delta-2022-12-07/en/clips/'

# Load the metadata
metadata = pd.read_csv(metadata_path, sep='\t')

# Filter the dataset to include only audio files listed in validated.tsv
metadata = metadata[['path', 'sentence']]
metadata['path'] = metadata['path'].apply(lambda x: os.path.join(clips_path, x))

# Convert metadata to Hugging Face Dataset
dataset = Dataset.from_pandas(metadata)

# Reduce the dataset size to avoid crashing Colab RAM (optional)
dataset = dataset.shuffle(seed=42).select(range(2500))  # Adjust the range as needed

# Split the dataset: 2000 samples for train, 500 samples for test
train_test_split = dataset.train_test_split(test_size=500)
common_voice = DatasetDict({
    "train": train_test_split["train"],
    "test": train_test_split["test"]
})

# Load processor
from transformers import WhisperProcessor
processor = WhisperProcessor.from_pretrained(model_name, language="english", task="transcribe")

def load_audio(batch):
    path = batch["path"]
    audio_array, sampling_rate = librosa.load(path, sr=processor.feature_extractor.sampling_rate)
    batch["audio"] = {
        "array": audio_array,
        "sampling_rate": sampling_rate
    }
    return batch

# Load the audio files
common_voice = common_voice.map(load_audio)
# Set sampling rate
sampling_rate = processor.feature_extractor.sampling_rate
common_voice = common_voice.cast_column("audio", Audio(sampling_rate=sampling_rate))
# Define noise reduction function
def reduce_noise(audio_array, sample_rate):
    reduced_noise = nr.reduce_noise(y=audio_array, sr=sample_rate)
    return reduced_noise
# Define normalization function
def normalize_audio(audio_array):
    norm_audio = librosa.util.normalize(audio_array)
    return norm_audio

# Preprocess audio data
def preprocess_audio(example):
    audio = example["audio"]["array"]
    sample_rate = example["audio"]["sampling_rate"]

    # Apply noise reduction
    audio = reduce_noise(audio, sample_rate)

    # Normalize audio
    audio = normalize_audio(audio)

    example["audio"]["array"] = audio
    return example
# Apply preprocessing to the training set
common_voice = common_voice.map(preprocess_audio)
# Set sampling rate
sampling_rate = processor.feature_extractor.sampling_rate
common_voice = common_voice.cast_column("audio", Audio(sampling_rate=sampling_rate))

def prepare_dataset(example):
    audio = example["audio"]
    example = processor(
        audio=audio["array"],
        sampling_rate=audio["sampling_rate"],
        text=example["sentence"],
    )
    example["input_length"] = len(audio["array"]) / audio["sampling_rate"]
    return example

common_voice = common_voice.map(
    prepare_dataset, remove_columns=["audio", "sentence"], num_proc=1
)

# Filter dataset by audio length
max_input_length = 6000.0

def is_audio_in_length_range(length):
    return length < max_input_length

common_voice["train"] = common_voice["train"].filter(
    is_audio_in_length_range,
    input_columns=["input_length"],
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Filter:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
common_voice
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['path', 'input_features', 'labels', 'input_length'],
#         num_rows: 2000
#     })
#     test: Dataset({
#         features: ['path', 'input_features', 'labels', 'input_length'],
#         num_rows: 500
#     })
# })

# %%
# Filter dataset by audio length
max_input_length = 6000.0

def is_audio_in_length_range(length):
    return length > max_input_length

common_voice["train"] = common_voice["train"].filter(
    is_audio_in_length_range,
    input_columns=["input_length"],
)
# Out:
# Filter:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
# Define data collator
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        input_features = [
            {"input_features": feature["input_features"][0]} for feature in features
        ]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        label_features = [{"input_ids": feature["labels"]} for feature in features]
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        labels = labels_batch["input_ids"].masked_fill(
            labels_batch.attention_mask.ne(1), -100
        )
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels
        return batch

data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
import evaluate
from transformers.models.whisper.english_normalizer import BasicTextNormalizer

metric_wer = evaluate.load("wer")
metric_cer = evaluate.load("cer")
normalizer = BasicTextNormalizer()

# %%
from transformers.models.whisper.english_normalizer import BasicTextNormalizer

normalizer = BasicTextNormalizer()


# Compute metrics function

def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # Replace -100 with the pad_token_id
    label_ids[label_ids == -100] = processor.tokenizer.pad_token_id

    # Decode predictions and labels
    pred_str = processor.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = processor.batch_decode(label_ids, skip_special_tokens=True)

    # Compute orthographic WER and CER
    wer_ortho = 100 * metric_wer.compute(predictions=pred_str, references=label_str)
    cer_ortho = 100 * metric_cer.compute(predictions=pred_str, references=label_str)

    # Normalize predictions and labels
    pred_str_norm = [normalizer(pred) for pred in pred_str]
    label_str_norm = [normalizer(label) for label in label_str]

    # Filter out empty references
    pred_str_norm = [pred_str_norm[i] for i in range(len(pred_str_norm)) if len(label_str_norm[i]) > 0]
    label_str_norm = [label_str_norm[i] for i in range(len(label_str_norm)) if len(label_str_norm[i]) > 0]

    # Compute normalized WER and CER
    wer = 100 * metric_wer.compute(predictions=pred_str_norm, references=label_str_norm)
    cer = 100 * metric_cer.compute(predictions=pred_str_norm, references=label_str_norm)

    return {"wer_ortho": wer_ortho, "cer_ortho": cer_ortho, "wer": wer, "cer": cer}

# %%
from transformers import WhisperProcessor, WhisperForConditionalGeneration, WhisperConfig, Seq2SeqTrainingArguments, Seq2SeqTrainer

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer, EarlyStoppingCallback
from functools import partial

# Update the model configuration if needed
model.config.use_cache = False
model.generate = partial(
    model.generate, language="english", task="transcribe", use_cache=True
)

# Define data collator
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        input_features = [
            {"input_features": feature["input_features"][0]} for feature in features
        ]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        label_features = [{"input_ids": feature["labels"]} for feature in features]
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        labels = labels_batch["input_ids"].masked_fill(
            labels_batch.attention_mask.ne(1), -100
        )
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels
        return batch

data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer, EarlyStoppingCallback, TrainerCallback
from functools import partial
from dataclasses import dataclass
from typing import Any, Dict, List, Union
import shutil

# %%
print("Total dataset size:", len(common_voice))
print("Training set size:", len(common_voice["train"]))
print("Test set size:", len(common_voice["test"]))
# Out:
# Total dataset size: 2
# Training set size: 0
# Test set size: 500

# %%
# Define training arguments
training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-small-dv-lii",
    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,
    learning_rate=1e-4,  # Example of a lower learning rate
    lr_scheduler_type="cosine",  # Using cosine scheduler
    warmup_steps=500,  # Warmup steps
    max_steps=1000,  # Total training steps
    gradient_checkpointing=True,
    fp16=True,
    fp16_full_eval=True,
    eval_strategy="steps",
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=500,
    eval_steps=500,
    logging_steps=50,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=True,
    weight_decay=0.1,  # Adding weight decay
)

# %%
from transformers import TrainerCallback

# %%
# Define callback to save the model after training
class SaveModelCallback(TrainerCallback):
    def on_train_end(self, args, state, control, **kwargs):
        # Save the model to Google Drive
        output_dir = "/content/drive/MyDrive/whisper-small-dv-lii"
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        shutil.copytree(args.output_dir, output_dir, dirs_exist_ok=True)
        print(f"Model saved to {output_dir}")

# Initialize trainer with the callback
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["train"],
    eval_dataset=common_voice["test"],
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor,
    callbacks=[SaveModelCallback]
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Continue training
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 43:20, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer Ortho</th>
#       <th>Cer Ortho</th>
#       <th>Wer</th>
#       <th>Cer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.231200</td>
#       <td>0.835013</td>
#       <td>27.689010</td>
#       <td>11.849300</td>
#       <td>23.088714</td>
#       <td>10.503672</td>
#     </tr>
#   </tbody>
# </table><p>
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].
# Model saved to /content/drive/MyDrive/whisper-small-dv
# TrainOutput(global_step=500, training_loss=1.0603566131591797, metrics={'train_runtime': 2528.3522, 'train_samples_per_second': 3.164, 'train_steps_per_second': 0.198, 'total_flos': 2.30868320256e+18, 'train_loss': 1.0603566131591797, 'epoch': 4.0})

# %%
# Assuming you're loading from a CSV or similar:
import pandas as pd

metadata_path = '/content/cv-corpus-12.0-delta-2022-12-07/en/validated.tsv'
metadata = pd.read_csv(metadata_path, sep='\t')
print("Total records in metadata:", metadata.shape[0])

if metadata.empty:
    print("Metadata is empty. Check the file path and contents.")
# Out:
# Total records in metadata: 6717

# %%
from datasets import Dataset

# Convert to Hugging Face dataset
dataset = Dataset.from_pandas(metadata)

# Splitting the dataset
train_test_split = dataset.train_test_split(test_size=0.2)  # Adjust test size as necessary
print("Training set size after split:", len(train_test_split['train']))
print("Test set size after split:", len(train_test_split['test']))

if len(train_test_split['train']) == 0:
    print("No data in training set after split. Adjust split parameters.")
# Out:
# Training set size after split: 3907
# Test set size after split: 977

# %%
# Filter to include only audio files listed and maybe add another condition if needed
metadata = metadata[['path', 'sentence']]

# Example of a potentially overly restrictive filter:
metadata = metadata[metadata['sentence'].str.len() > 50]  # Example: filtering on sentence length
print("Filtered dataset size:", len(metadata))

if metadata.empty:
    print("All records filtered out. Adjust filter conditions.")
# Out:
# Filtered dataset size: 4884

# %%
# Adjust paths to full paths
metadata['path'] = metadata['path'].apply(lambda x: os.path.join(clips_path, x))

# Assuming you're loading and processing audio here
def load_audio(file_path):
    # Just a placeholder function
    # Replace with actual audio loading code
    return os.path.exists(file_path)

# Filter dataset to include only existing audio files
metadata = metadata[metadata['path'].apply(load_audio)]
print("Dataset size after checking for audio file existence:", len(metadata))

if len(metadata) == 0:
    print("No valid audio files found. Check audio file paths and availability.")
# Out:
# Dataset size after checking for audio file existence: 4884

# %%
# Continue training
trainer.train()
import h5py

def save_model_to_h5(model, h5_path):
    with h5py.File(h5_path, 'w') as h5file:
        for name, param in model.named_parameters():
            h5file.create_dataset(name, data=param.detach().cpu().numpy())

# Example usage after training
h5_file_path = "/content/drive/MyDrive/whisper_model_weights_safouh.h5"
save_model_to_h5(model, h5_file_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
#     <div>
#
#       <progress value='501' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 501/1000 35:30 < 35:30, 0.23 it/s, Epoch 4/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer Ortho</th>
#       <th>Cer Ortho</th>
#       <th>Wer</th>
#       <th>Cer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.070900</td>
#       <td>0.167142</td>
#       <td>10.893417</td>
#       <td>6.030748</td>
#       <td>9.763143</td>
#       <td>5.767967</td>
#     </tr>
#   </tbody>
# </table><p>
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='1001' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1000 1:17:24, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer Ortho</th>
#       <th>Cer Ortho</th>
#       <th>Wer</th>
#       <th>Cer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.070900</td>
#       <td>0.167142</td>
#       <td>10.893417</td>
#       <td>6.030748</td>
#       <td>9.763143</td>
#       <td>5.767967</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.004200</td>
#       <td>0.221544</td>
#       <td>13.342476</td>
#       <td>7.722181</td>
#       <td>12.073946</td>
#       <td>7.367626</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-a45799c18546> in <cell line: 2>()
#       1 # Continue training
# ----> 2 trainer.train()
#       3 import h5py
#       4
#       5 def save_model_to_h5(model, h5_path):
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1874                 # Disable progress bars when uploading models during checkpoints to avoid polluting stdout
#    1875                 hf_hub_utils.disable_progress_bars()
# -> 1876                 return inner_training_loop(
#    1877                     args=args,
#    1878                     resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2371                     shutil.rmtree(checkpoint)
#    2372
# -> 2373         self.control = self.callback_handler.on_train_end(args, self.state, self.control)
#    2374
#    2375         # Wait for the checkpoint to be uploaded.
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer_callback.py in on_train_end(self, args, state, control)
#     455
#     456     def on_train_end(self, args: TrainingArguments, state: TrainerState, control: TrainerControl):
# --> 457         return self.call_event("on_train_end", args, state, control)
#     458
#     459     def on_epoch_begin(self, args: TrainingArguments, state: TrainerState, control: TrainerControl):
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer_callback.py in call_event(self, event, args, state, control, **kwargs)
#     496     def call_event(self, event, args, state, control, **kwargs):
#     497         for callback in self.callbacks:
# --> 498             result = getattr(callback, event)(
#     499                 args,
#     500                 state,
#
# <ipython-input-32-6f225708e1e9> in on_train_end(self, args, state, control, **kwargs)
#       6         if not os.path.exists(output_dir):
#       7             os.makedirs(output_dir)
# ----> 8         shutil.copytree(args.output_dir, output_dir, dirs_exist_ok=True)
#       9         print(f"Model saved to {output_dir}")
#      10
#
# NameError: name 'shutil' is not defined

# %%
bbnnorooogppimport h5py
import torch
from transformers import WhisperForConditionalGeneration, WhisperConfig, WhisperProcessor, WhisperTokenizer



# Load the processor and tokenizer
processor = WhisperProcessor.from_pretrained(model_name, language="english", task="transcribe")
tokenizer = WhisperTokenizer.from_pretrained(model_name)

# Manually set forced_decoder_ids for the English language
english_language_token_id = tokenizer.convert_tokens_to_ids("<<en>>")
model.config.forced_decoder_ids = [[0, english_language_token_id]]

# Ensure that the generation configuration is correctly applied
model.generation_config.language = "en"
model.generation_config.task = "transcribe"
model.generation_config.forced_decoder_ids = [[0, english_language_token_id]]
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer, EarlyStoppingCallback, TrainerCallback
from functools import partial
from dataclasses import dataclass
from typing import Any, Dict, List, Union
import shutil

# Define data collator
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        input_features = [
            {"input_features": feature["input_features"][0]} for feature in features
        ]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        label_features = [{"input_ids": feature["labels"]} for feature in features]
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        labels = labels_batch["input_ids"].masked_fill(
            labels_batch.attention_mask.ne(1), -100
        )
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels
        return batch

data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# Define training arguments
training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-small-dv",
    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,
    learning_rate=1e-4,  # Example of a lower learning rate
    lr_scheduler_type="cosine",  # Using cosine scheduler
    warmup_steps=500,  # Warmup steps
    max_steps=1000,  # Total training steps
    gradient_checkpointing=True,
    fp16=True,
    fp16_full_eval=True,
    eval_strategy="steps",
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=500,
    eval_steps=500,
    logging_steps=50,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=True,
    weight_decay=0.1,  # Adding weight decay
)

# Define callback to save the model after training
class SaveModelCallback(TrainerCallback):
    def on_train_end(self, args, state, control, **kwargs):
        # Save the model to Google Drive
        output_dir = "/content/drive/MyDrive/whisper-small-dv"
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        shutil.copytree(args.output_dir, output_dir, dirs_exist_ok=True)
        print(f"Model saved to {output_dir}")

# Initialize trainer with the callback
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["train"],  # Assuming common_voice is already loaded and processed
    eval_dataset=common_voice["test"],  # Assuming common_voice is already loaded and processed
    data_collator=data_collator,
    compute_metrics=compute_metrics,  # Assuming compute_metrics is already defined
    tokenizer=processor,
    callbacks=[SaveModelCallback]
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Continue training
trainer.train()

# Save the updated model weights to the same H5 file
save_model_to_h5(model, h5_file_path)
print(f"Model weights saved to {h5_file_path}")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 50:47, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer Ortho</th>
#       <th>Cer Ortho</th>
#       <th>Wer</th>
#       <th>Cer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>600</td>
#       <td>0.072600</td>
#       <td>1.288772</td>
#       <td>33.710055</td>
#       <td>15.420841</td>
#       <td>29.488408</td>
#       <td>14.049106</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].
# Model saved to /content/drive/MyDrive/whisper-small-dv
# Model weights saved to /content/drive/MyDrive/whisper_model_weights.h5

# %%
import h5py
import torch
from transformers import WhisperForConditionalGeneration, WhisperConfig, WhisperProcessor, WhisperTokenizer

def load_model_from_h5(model, h5_path):
    with h5py.File(h5_path, 'r') as h5file:
        for name, param in model.named_parameters():
            param_data = torch.tensor(h5file[name][...])
            param.data.copy_(param_data)

model_name = "openai/whisper-small"  # Use the appropriate model name
h5_file_path = "/content/drive/MyDrive/whisper_model_weights.h5"

# Load the configuration and model architecture
config = WhisperConfig.from_pretrained(model_name)
config.dropout = 0.1  # Set dropout to 0.1

model = WhisperForConditionalGeneration.from_pretrained(model_name, config=config)
load_model_from_h5(model, h5_file_path)

# Load the processor and tokenizer
processor = WhisperProcessor.from_pretrained(model_name, language="english", task="transcribe")
tokenizer = WhisperTokenizer.from_pretrained(model_name)

# Manually set forced_decoder_ids for the English language
english_language_token_id = tokenizer.convert_tokens_to_ids("<<en>>")
model.config.forced_decoder_ids = [[0, english_language_token_id]]

# Ensure that the generation configuration is correctly applied
model.generation_config.language = "en"
model.generation_config.task = "transcribe"
model.generation_config.forced_decoder_ids = [[0, english_language_token_id]]
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer, EarlyStoppingCallback, TrainerCallback
from functools import partial
from dataclasses import dataclass
from typing import Any, Dict, List, Union
import shutil

# Define data collator
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        input_features = [
            {"input_features": feature["input_features"][0]} for feature in features
        ]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        label_features = [{"input_ids": feature["labels"]} for feature in features]
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        labels = labels_batch["input_ids"].masked_fill(
            labels_batch.attention_mask.ne(1), -100
        )
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels
        return batch

data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# Define training arguments
training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-small-dv",
    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,
    learning_rate=1e-4,  # Example of a lower learning rate
    lr_scheduler_type="linear",  # Using cosine scheduler
    warmup_steps=500,  # Warmup steps
    max_steps=500,  # Total training steps
    gradient_checkpointing=True,
    fp16=True,
    fp16_full_eval=True,
    eval_strategy="steps",
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=500,
    eval_steps=500,
    logging_steps=50,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=True,
    weight_decay=0.1,  # Adding weight decay
)

# Define callback to save the model after training
class SaveModelCallback(TrainerCallback):
    def on_train_end(self, args, state, control, **kwargs):
        # Save the model to Google Drive
        output_dir = "/content/drive/MyDrive/whisper-small-dv"
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        shutil.copytree(args.output_dir, output_dir, dirs_exist_ok=True)
        print(f"Model saved to {output_dir}")

# Initialize trainer with the callback
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["train"],  # Assuming common_voice is already loaded and processed
    eval_dataset=common_voice["test"],  # Assuming common_voice is already loaded and processed
    data_collator=data_collator,
    compute_metrics=compute_metrics,  # Assuming compute_metrics is already defined
    tokenizer=processor,
    callbacks=[SaveModelCallback]
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Start training
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='76' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 76/500 05:14 < 30:03, 0.24 it/s, Epoch 0.60/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='501' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 35:37, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer Ortho</th>
#       <th>Cer Ortho</th>
#       <th>Wer</th>
#       <th>Cer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.072600</td>
#       <td>1.804041</td>
#       <td>38.659392</td>
#       <td>18.259111</td>
#       <td>34.661813</td>
#       <td>16.941093</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}

# %%
# Save the updated model weights to the same H5 file
save_model_to_h5(model, h5_file_path)
print(f"Model weights saved to {h5_file_path}")

# %%
# Continue training
trainer.train()
import h5py

def save_model_to_h5(model, h5_path):
    with h5py.File(h5_path, 'w') as h5file:
        for name, param in model.named_parameters():
            h5file.create_dataset(name, data=param.detach().cpu().numpy())

# Example usage after training
h5_file_path = "/content/drive/MyDrive/whisper_model_weights_new.h5"
save_model_to_h5(model, h5_file_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='1000' max='1000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1000/1000 1:25:34, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer Ortho</th>
#       <th>Cer Ortho</th>
#       <th>Wer</th>
#       <th>Cer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.088600</td>
#       <td>0.458286</td>
#       <td>17.927664</td>
#       <td>8.697303</td>
#       <td>15.421640</td>
#       <td>7.995718</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.004900</td>
#       <td>0.497752</td>
#       <td>19.843597</td>
#       <td>9.276491</td>
#       <td>16.750096</td>
#       <td>8.482273</td>
#     </tr>
#   </tbody>
# </table><p>
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].
# Model saved to /content/drive/MyDrive/whisper-small-dv

# %%
import h5py
import torch
from transformers import WhisperForConditionalGeneration, WhisperConfig, WhisperProcessor, WhisperTokenizer

def load_model_from_h5(model, h5_path):
    with h5py.File(h5_path, 'r') as h5file:
        for name, param in model.named_parameters():
            param_data = torch.tensor(h5file[name][...])
            param.data.copy_(param_data)

model_name = "openai/whisper-small"  # Use the appropriate model name
h5_file_path = "/content/drive/MyDrive/whisper_model_weights_new.h5"

# Load the configuration and model architecture
config = WhisperConfig.from_pretrained(model_name)
config.dropout = 0.1  # Set dropout to 0.1

model = WhisperForConditionalGeneration.from_pretrained(model_name, config=config)
load_model_from_h5(model, h5_file_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer, EarlyStoppingCallback, TrainerCallback
from functools import partial
from dataclasses import dataclass
from typing import Any, Dict, List, Union
import shutil

# Define data collator
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        input_features = [
            {"input_features": feature["input_features"][0]} for feature in features
        ]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        label_features = [{"input_ids": feature["labels"]} for feature in features]
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        labels = labels_batch["input_ids"].masked_fill(
            labels_batch.attention_mask.ne(1), -100
        )
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels
        return batch

data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# Define training arguments
training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-small-dv",
    per_device_train_batch_size=8,
    gradient_accumulation_steps=2,
    learning_rate=1e-4,  # Example of a lower learning rate
    lr_scheduler_type="cosine",  # Using cosine scheduler
    warmup_steps=500,  # Warmup steps
    max_steps=500,  # Total training steps
    gradient_checkpointing=True,
    fp16=True,
    fp16_full_eval=True,
    eval_strategy="steps",
    per_device_eval_batch_size=8,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=500,
    eval_steps=500,
    logging_steps=50,
    report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=True,
    weight_decay=0.1,  # Adding weight decay
)

# Define callback to save the model after training
class SaveModelCallback(TrainerCallback):
    def on_train_end(self, args, state, control, **kwargs):
        # Save the model to Google Drive
        output_dir = "/content/drive/MyDrive/whisper-small-dv"
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
        shutil.copytree(args.output_dir, output_dir, dirs_exist_ok=True)
        print(f"Model saved to {output_dir}")

# Initialize trainer with the callback
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["train"],  # Assuming common_voice is already loaded and processed
    eval_dataset=common_voice["test"],  # Assuming common_voice is already loaded and processed
    data_collator=data_collator,
    compute_metrics=compute_metrics,  # Assuming compute_metrics is already defined
    tokenizer=processor,
    callbacks=[SaveModelCallback]
)
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Continue training
trainer.train()
import h5py

def save_model_to_h5(model, h5_path):
    with h5py.File(h5_path, 'w') as h5file:
        for name, param in model.named_parameters():
            h5file.create_dataset(name, data=param.detach().cpu().numpy())

# Example usage after training
h5_file_path = "/content/drive/MyDrive/whisper_model_weights_new_LAITHO.h5"
save_model_to_h5(model, h5_file_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:464: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# `use_cache = True` is incompatible with gradient checkpointing. Setting `use_cache = False`...
#     <div>
#
#       <progress value='500' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 45:32, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer Ortho</th>
#       <th>Cer Ortho</th>
#       <th>Wer</th>
#       <th>Cer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.083800</td>
#       <td>0.711171</td>
#       <td>25.434995</td>
#       <td>11.685023</td>
#       <td>22.198691</td>
#       <td>10.723669</td>
#     </tr>
#   </tbody>
# </table><p>
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 448, 'suppress_tokens': [1, 2, 7, 8, 9, 10, 14, 25, 26, 27, 28, 29, 31, 58, 59, 60, 61, 62, 63, 90, 91, 92, 93, 359, 503, 522, 542, 873, 893, 902, 918, 922, 931, 1350, 1853, 1982, 2460, 2627, 3246, 3253, 3268, 3536, 3846, 3961, 4183, 4667, 6585, 6647, 7273, 9061, 9383, 10428, 10929, 11938, 12033, 12331, 12562, 13793, 14157, 14635, 15265, 15618, 16553, 16604, 18362, 18956, 20075, 21675, 22520, 26130, 26161, 26435, 28279, 29464, 31650, 32302, 32470, 36865, 42863, 47425, 49870, 50254, 50258, 50360, 50361, 50362], 'begin_suppress_tokens': [220, 50257]}
# There were missing keys in the checkpoint model loaded: ['proj_out.weight'].
# Model saved to /content/drive/MyDrive/whisper-small-dv

# %%
IT IS CONSUMED DOMESTICALLY AND EXPORTED TO OTHER COUNTRIES

# %%
import torch
import librosa
from transformers import WhisperProcessor, WhisperForConditionalGeneration

# Define the path to the fine-tuned model checkpoint
fine_tuned_model_checkpoint = "/content/drive/MyDrive/whisper-small-dv/checkpoint-1000"  # Update with your actual path

# Load the fine-tuned model and processor
processor = WhisperProcessor.from_pretrained(fine_tuned_model_checkpoint)
model = WhisperForConditionalGeneration.from_pretrained(fine_tuned_model_checkpoint)

# Define the path to the test audio file
test_audio_path = "/content/drive/MyDrive/5-my-house.mp3"

# Load the audio file
audio_array, sampling_rate = librosa.load(test_audio_path, sr=processor.feature_extractor.sampling_rate)

# Preprocess the audio file
inputs = processor(audio=audio_array, sampling_rate=sampling_rate, return_tensors="pt")

# Generate transcription
with torch.no_grad():
    generated_ids = model.generate(inputs["input_features"])

# Decode the generated ids to text
transcription = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

# Print the transcription
print("Transcription:", transcription)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Transcription: M I live in a house. My house is small, my house has two beds rooms. My mother and dab sleep in one beds room.

# %%
import torch
import librosa
import numpy as np
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer

# Load the audio file
path = "/content/drive/MyDrive/5-my-house.mp3"
audio, sr = librosa.load(path, sr=16000)  # loading audio with sample rate of 16kHz

# Load pre-trained model and tokenizer
tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")






print("Transcription:", transcription)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Wav2Vec2CTCTokenizer'.
# The class this function is called from is 'Wav2Vec2Tokenizer'.
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1', 'wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Transcription: M I live in a house. My house is small, my house has two beds rooms. My mother and dab sleep in one beds room.

# %%
import torch
import librosa
from transformers import WhisperProcessor, WhisperForConditionalGeneration

# Define the path to the fine-tuned model checkpoint
fine_tuned_model_checkpoint = "/content/drive/MyDrive/whisper-small-dv/checkpoint-1000"  # Update with your actual path

# Load the fine-tuned model and processor
processor = WhisperProcessor.from_pretrained(fine_tuned_model_checkpoint)
model = WhisperForConditionalGeneration.from_pretrained(fine_tuned_model_checkpoint)

# Define the path to the test audio file
test_audio_path = "/content/54321-35890.mp3"

# Load the audio file
audio_array, sampling_rate = librosa.load(test_audio_path, sr=processor.feature_extractor.sampling_rate)

# Preprocess the audio file
inputs = processor(audio=audio_array, sampling_rate=sampling_rate, return_tensors="pt")

# Generate transcription
with torch.no_grad():
    generated_ids = model.generate(inputs["input_features"])

# Decode the generated ids to text
transcription = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

# Print the transcription
print("Transcription:", transcription)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Transcription: Ten, nine, eight, seven, six, five, four, three, two, one,
